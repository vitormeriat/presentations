# %% [markdown]
# ## Histogram of Gradients (Histograma de Gradientes)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np

from skimage import data, color, feature
import skimage.data
from scipy import misc

img = misc.imread('img/eu1.jpg')

image = color.rgb2gray(img)

hog_vec, hog_vis = feature.hog(image, visualise=True)

fig, ax = plt.subplots(1, 2, figsize=(16, 12),
                       subplot_kw=dict(xticks=[], yticks=[]))
ax[0].imshow(image, cmap='gray')
ax[0].set_title('input image')

ax[1].imshow(hog_vis)
ax[1].set_title('visualization of HOG features');
# Out:
# C:\Users\vitor\Anaconda3\envs\deeplearning\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\vitor\Anaconda3\envs\deeplearning\lib\site-packages\skimage\feature\_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
